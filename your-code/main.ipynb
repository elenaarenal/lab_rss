# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
#imports

# %pip install feedparser

import pandas as pd

import feedparser
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
#elpais

# %%
news=feedparser.parse('https://feeds.elpais.com/mrss-s/pages/ep/site/elpais.com/portada')

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
news.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'etag', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
news['entries'][0]
# Out:
# {'id': 'https://elpais.com/deportes/eurocopa-futbol/2024-07-01/cuanto-sabes-de-la-eurocopa.html',
#  'guidislink': True,
#  'link': 'https://elpais.com/deportes/eurocopa-futbol/2024-07-01/cuanto-sabes-de-la-eurocopa.html',
#  'title': '¿Cuánto sabes de la Eurocopa?',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://feeds.elpais.com/mrss-s/pages/ep/site/elpais.com/portada',
#   'value': '¿Cuánto sabes de la Eurocopa?'},
#  'published': 'Mon, 01 Jul 2024 16:21:23 GMT',
#  'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=1, tm_hour=16, tm_min=21, tm_sec=23, tm_wday=0, tm_yday=183, tm_isdst=0),
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://elpais.com/deportes/eurocopa-futbol/2024-07-01/cuanto-sabes-de-la-eurocopa.html'}],
#  'authors': [{'name': 'EL PAÍS'}],
#  'author': 'EL PAÍS',
#  'author_detail': {'name': 'EL PAÍS'},
# ...

# %%
news['entries'][0].keys()
# Out:
# dict_keys(['id', 'guidislink', 'link', 'title', 'title_detail', 'published', 'published_parsed', 'links', 'authors', 'author', 'author_detail', 'dcterms_alternative', 'summary', 'summary_detail', 'tags', 'media_content', 'media_credit', 'credit', 'content'])

# %%
df=pd.DataFrame(news['entries'])

# %%
df.head()
# Out:
#                                                   id  guidislink  \
# 0  https://elpais.com/deportes/eurocopa-futbol/20...        True
# 1  https://elpais.com/deportes/eurocopa-futbol/20...        True
# 2  https://elpais.com/internacional/2024-07-02/ri...        True
# 3  https://elpais.com/internacional/2024-07-02/la...        True
# 4  https://elpais.com/espana/2024-07-02/feijoo-de...        True
#
#                                                 link  \
# 0  https://elpais.com/deportes/eurocopa-futbol/20...
# 1  https://elpais.com/deportes/eurocopa-futbol/20...
# 2  https://elpais.com/internacional/2024-07-02/ri...
# 3  https://elpais.com/internacional/2024-07-02/la...
# 4  https://elpais.com/espana/2024-07-02/feijoo-de...
#
#                                                title  \
# 0                      ¿Cuánto sabes de la Eurocopa?
# 1  ¿Quién va a ganar la Eurocopa? Así arrancan la...
# 2  Rishi Sunak da por hecha su derrota y pide evi...
# ...

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
dfcolumns=df[['title','title_detail','author','links']]
dfcolumns
# Out:
#                                                  title  \
# 0                        ¿Cuánto sabes de la Eurocopa?
# 1    ¿Quién va a ganar la Eurocopa? Así arrancan la...
# 2    Rishi Sunak da por hecha su derrota y pide evi...
# 3    La derrota del presidente francés acelera el f...
# 4    Feijóo desconfía de la “imparcialidad” del Con...
# ..                                                 ...
# 135  Las gafas de sol Vans para hombre más estilosa...
# 136  Tres soluciones para evitar que se vuele el ma...
# 137  El cargador de pared para cepillos de dientes ...
# 138  El ventilador portátil que puedes llevar colga...
# 139  El pijama de mujer perfecto para verano: es el...
#
#                                           title_detail  \
# 0    {'type': 'text/plain', 'language': None, 'base...
# 1    {'type': 'text/plain', 'language': None, 'base...
# 2    {'type': 'text/plain', 'language': None, 'base...
# 3    {'type': 'text/plain', 'language': None, 'base...
# ...

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(df)
# Out:
# 140

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
entry_keys = df.columns
for key in entry_keys:
   print(key)
# Out:
# id
# guidislink
# link
# title
# title_detail
# published
# published_parsed
# links
# authors
# author
# author_detail
# dcterms_alternative
# summary
# summary_detail
# tags
# media_content
# media_credit
# credit
# content
# media_text
# media_thumbnail
# href

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
entry_titles = df['title']
lst=[]
for title in entry_titles:
    lst.append(title)
lst
# Out:
# ['¿Cuánto sabes de la Eurocopa?',
#  '¿Quién va a ganar la Eurocopa? Así arrancan las predicciones de nuestro modelo estadístico',
#  'Rishi Sunak da por hecha su derrota y pide evitar una “supermayoría” del Partido Laborista',
#  'La derrota del presidente francés acelera el fin del macronismo',
#  'Feijóo desconfía de la “imparcialidad” del Constitucional y agotará el plazo para recurrir la amnistía',
#  'El retorno de Puigdemont queda en el aire, pero el plan sigue: ni una “gamberrada” ni emular a Tarradellas',
#  'Amnistiados los 46 policías procesados por las cargas del referéndum del 1-O',
#  'Así queda el reparto de plazas de la oferta de empleo público: 31.000 a la Administración General, 3.200 a la Guardia Civil, 2.900 a la Policía y 2.700 militares',
#  'El mercado laboral abre la temporada de verano con 71.000 nuevos trabajadores y 47.000 parados menos',
# ...

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
#i don't understand this question

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
df=pd.DataFrame(news['entries'])

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
print(df['author'].value_counts())
df.sort_values(by=['author'],ascending=False)
# Out:
# author
# EL PAÍS                                   11
# jordi perez                                3
# Marita Alonso                              3
# Agencias  .                                2
# Alejandro Ciriza Istúriz                   2
#                                           ..
# Paola  Lo Cascio                           1
# Bernat Coll                                1
# Ginés Donaire                              1
# Pablo Sempere ,Yolanda Clemente Pomeda     1
# David Rodríguez Madera                     1
# Name: count, Length: 112, dtype: int64
#                                                     id  guidislink  \
# 11   https://elpais.com/internacional/2024-07-02/vi...        True
# 44   https://elpais.com/tecnologia/2024-07-02/angel...        True
# 101  https://elpais.com/tecnologia/2024-07-01/el-go...        True
# 103  https://elpais.com/tecnologia/2024-07-01/un-re...        True
# 29   https://elpais.com/opinion/2024-07-02/ni-levia...        True
# ...

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_lenght']=df['title'].str.len()
df.sort_values(by=['title_lenght'],ascending=False)
# Out:
#                                                     id  guidislink  \
# 7    https://elpais.com/economia/2024-07-02/31000-a...        True
# 39   https://elpais.com/deportes/eurocopa-futbol/20...        True
# 58   https://elpais.com/cultura/2024-07-01/falsestu...        True
# 84   https://elpais.com/espana/2024-07-02/barones-d...        True
# 119  https://elpais.com/eps/2024-06-29/lila-ibrahim...        True
# ..                                                 ...         ...
# 61   https://elpais.com/television/2024-07-02/yo-so...        True
# 32   https://elpais.com/opinion/2024-07-02/bardella...        True
# 29   https://elpais.com/opinion/2024-07-02/ni-levia...        True
# 28   https://elpais.com/opinion/2024-07-02/justicia...        True
# 33   https://elpais.com/opinion/2024-07-02/el-roto....        True
#
#                                                   link  \
# 7    https://elpais.com/economia/2024-07-02/31000-a...
# ...

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
df=df[df['summary'].str.contains('machine learning')]
df.head()

#none of them
# Out:
# Empty DataFrame
# Columns: [id, guidislink, link, title, title_detail, published, published_parsed, links, authors, author, author_detail, dcterms_alternative, summary, summary_detail, tags, media_content, media_credit, credit, content, media_text, media_thumbnail, href, title_lenght]
# Index: []
#
# [0 rows x 23 columns]
